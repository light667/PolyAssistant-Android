# %% [markdown]
# # Calcul différentiel
# ## Fonction, courbe, limite
#
# A traiter avec:
#
# - **sympy**
#   ```Python
#    import sympy as sp
#   ```
#
# - **numpy et matplotlib**
#
#   ```Python
#    import numpy as np
#    import matplotlib.pyplot as plt
#   ```

# %% [markdown]
# Soient la fonction $f$ définie sur $\mathbb{R}\setminus\left\{ -1;\,1\right\} $ par $f\left(x\right)=\dfrac{3x^{2}-4}{x^{2}-1}$ et $C_{f}$ sa courbe représentative.
# On cherche les limites aux bornes de l’ensemble de définitions.

# %%
import sympy as sp # importation de sympy comme sp
x=sp.Symbol('x')
# définition du symbole x
f=sp.Function('f') # définition du symbole de la fonction
f=(3*x**2-4)/(x**2-1)
# définition de la fonction
display(f)
# affichage de la fonction
display(r'la courbe de f pour x=[-10,10]')
sp.plot(f)
# traçage de la courbe de f pour x=[-10,10]
display(r'la courbe de f pour x=[0,10]')
sp.plot(f,(x,1.5,10)) # traçage de la courbe de f pour x=[1.5,10]
sp.plot(f,(x,-10,-2)) # traçage de la courbe de f pour x=[-10.,-2]
# Out:
# (3*x**2 - 4)/(x**2 - 1)
# 'la courbe de f pour x=[-10,10]'
# 'la courbe de f pour x=[0,10]'

# %%
# Votre travail

# %% [markdown]
# On va donc remplir des tableaux de la forme:
#
# 1. pour ${\displaystyle \lim_{x\to+\infty}}f\left(x\right)$
#
# |$x$ | $10^{2}\qquad$ | $10^{3}\qquad$ | $10^{4}\qquad$ | $10^{6}\qquad$ |
# |------|------|------|------|------|
# |$f\left(x\right)$ |  |  |  | |
#
# lorsque $x\to+\infty$, la fonction $f$ tend vers...
#
# 2.  pour ${\displaystyle \lim_{x\to-\infty}}f\left(x\right)$
#
# | $x$ | $-10^{6}\qquad$ | $-10^{4}\qquad$ | $-10^{3}\qquad$ | $-10^{2}\qquad$ |
# |------|------|------|------|------|
# | $f\left(x\right)$ |  |  |  |  |
#
# lorsque $x\to-\infty$, la fonction $f$ tend vers...
#
# 3.  pour ${\displaystyle \lim_{x\to-1^{-}}}f\left(x\right)$\\
#
# | $x$ | $-\left(1+10^{-2}\right)\qquad$ | $-\left(1+10^{-3}\right)\qquad$ | $-\left(1+10^{-4}\right)\qquad$ | $-\left(1+10^{-6}\right)\qquad$ |
# |------|------|------|------|------|
# | $f\left(x\right)$ |  |  |  |  |
#
# lorsque $x\to-1^{-}$, la fonction $f$ tend vers...
#
# 4. pour ${\displaystyle \lim_{x\to-1^{+}}}f\left(x\right)$\\
#
# |$x$ | $-1+10^{-6}\qquad$ | $-1+10^{-4}\qquad$ | $-1+10^{-3}\qquad$ | $-1+10^{-2}\qquad$ |
# |------|------|------|------|------|
# | $f\left(x\right)$ |   |  |   |   |
#
# lorsque $x\to-1^{+}$, la fonction $f$ tend vers...
#
# 5.  pour ${\displaystyle \lim_{x\to1^{-}}}f\left(x\right)$
#
# | $x$ | $1+10^{-2}\qquad$ | $1+10^{-3}\qquad$ | $1+10^{-4}\qquad$ | $1+10^{-6}\qquad$ |
# |------|------|------|------|------|
# $f\left(x\right)$ |  |  |  |  |
#
# lorsque $x\to1^{-}$, la fonction $f$ tend vers...
#
# 6.  pour ${\displaystyle \lim_{x\to1^{+}}}f\left(x\right)$
#
# | $x$ | $1+10^{-6}\qquad$ | $1+10^{-4}\qquad$ | $1+10^{-3}\qquad$ | $1+10^{-2}\qquad$ |
# |------|------|------|------|------|
# | $f\left(x\right)$ |  |  |  |  |
#
# lorsque $x\to1^{+}$, la fonction $f$ tend vers...

# %% [markdown]
# **Qu'obtient-on avec `sympy`?**

# %% [markdown]
# **Reprendre le travail avec :**
#
# 1. ${\displaystyle \lim_{x\to 0}\dfrac{\sin(x)}{x}}$
# 2. ${\displaystyle \lim_{x\to 0}\dfrac{1}{x}}$
